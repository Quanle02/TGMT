# %%
from PIL import Image

# %%
dir = 'D:/tgmt_img'

# %%
image_path = dir + '/img01.jpg'
print(image_path)
# Out:
# D:/tgmt_img/img01.jpg

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x618>

# %%
print("Định dang ảnh: ", img01.format)
# Out:
# Định dang ảnh:  JPEG

# %%
print("Kích thước hình ảnh: ", img01.size)
# Out:
# Kích thước hình ảnh:  (400, 618)

# %%
new_img_01_path = dir + '/new_01.JPG'
new_img_png_01_path = dir + '/new_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)

# %%
img01.close()
